# %% [markdown]
# <a href="https://colab.research.google.com/github/mdmasoomcse/TNS-prcatice-sessions/blob/main/TNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[]
a=list1.append(input("Enter 1 movie name"))
b=list1.append(input("Enter 2 movie name"))
c=list1.append(input("Enter 3 movie name"))
d=list1.append(input("Enter 4 movie name"))
print(list1)
# Out:
# Enter 1 movie nameRRR
# Enter 2 movie nameRagghvarun
# Enter 3 movie nameBahu
# Enter 4 movie nameMaharshi
# ['RRR', 'Ragghvarun', 'Bahu', 'Maharshi']

# %%
#check palindrome
list1=[1,2,3]
copy_list1=list1.copy()
copy_list1.reverse()

if list1==copy_list1:
  print("It is palindrome!!")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %%
grade=("C","D","A","A","B","B","A")
print(grade.count("A"))
# Out:
# 3

# %%
grade=["C","D","A","A","B","B","A"]
grade.sort()
print(grade)
# Out:
# ['A', 'A', 'A', 'B', 'B', 'C', 'D']

# %%
#Dictionaries--
dict={
    "name":"masoom",
    "cgpa":7.8,
    "college":"JNTUH",
    "skills":["Web developer","Data analytics","QA"]
}
print(dict["skills"])
print(dict)
new_dict={}
new_dict["age"]=22
print(new_dict)
# Out:
# ['Web developer', 'Data analytics', 'QA']
# {'name': 'masoom', 'cgpa': 7.8, 'college': 'JNTUH', 'skills': ['Web developer', 'Data analytics', 'QA']}
# {'age': 22}

# %%
#nested dictionary--
new_dict={
    "name":"masoom",
    "subject":{
        "phy":22,
        "chem":23,
        "math":24
    }
}
print(new_dict["subject"])
print(new_dict["subject"]["math"])
# Out:
# {'phy': 22, 'chem': 23, 'math': 24}
# 24

# %%
#methods-
#dict.keys()
#values()
#items()
#get()
#update(newdict)

dict={
    "name":"masoom",
    "cgpa":7.8,
    "college":"JNTUH",
    "skills":["Web developer","Data analytics","QA"]
}
print(dict.keys())
print(dict.values())
print(dict.items())
# Out:
# dict_keys(['name', 'cgpa', 'college', 'skills'])
# dict_values(['masoom', 7.8, 'JNTUH', ['Web developer', 'Data analytics', 'QA']])
# dict_items([('name', 'masoom'), ('cgpa', 7.8), ('college', 'JNTUH'), ('skills', ['Web developer', 'Data analytics', 'QA'])])

# %%
#practice
